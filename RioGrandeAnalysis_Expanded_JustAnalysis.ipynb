# %% [markdown]
# # Connecting NDVI, Groundwater, and Stream Disconnection During Drought: Case Study along the Rio Grande
# Danielle Tadych
# Revised Notebook 8/2023
#
# This notebook is to expand upon our analysis from the Data challenge but to include more sophisticated data collection and analysis techniques.
#
# For the previous report, see DataChallengeReport_RioGrandeAnalysis.ipynb.
#
# In order to run this code, you need to have downloaded scenes from "Making_An_Order.ipynb".

# %% [markdown]
# ## Full Analysis Code
#
# This section starts the process of an order

# %%
# Import Packages
import numpy as np
import matplotlib.pyplot as plt
import os, glob
import json
import requests
import time
from requests.auth import HTTPBasicAuth
from osgeo import gdal
import subprocess
import datetime
import xarray as xr
import rioxarray as rxr
import pandas as pd
import geopandas as gp
import pathlib
from planet import Session, DataClient, OrdersClient
import geojsonio
import shutil
import rasterio.plot as show
print("packages loaded.")
# Out:
# packages loaded.

# %% [markdown]
# Unzipping and moving the files to the data folder

# %%
import zipfile

for i in ordernums:
    specific_order = orders[i]
    order_id = specific_order['id']
    order_name = specific_order['name']
    path_to_zip_file = 'Data/'+order_id+"/"+order_name+"_"+order_id+'.zip'
    directory_to_extract_to = './Data/MES_48R'
    print(path_to_zip_file)
    with zipfile.ZipFile(path_to_zip_file, 'r') as zip_ref:
       zip_ref.extractall(directory_to_extract_to)
# Out:
# Data/c8fd3bdb-c472-45b2-920d-b2d0f2774988/MES_48R09_12_2023REOrthoTile_2016-2020_order_test_c8fd3bdb-c472-45b2-920d-b2d0f2774988.zip
# Data/00e22f98-edf0-4d17-a8f2-67daf2acc613/MES_48R09_12_2023PSOrthoTile_2016-2020_order_test_00e22f98-edf0-4d17-a8f2-67daf2acc613.zip

# %% [markdown]
# ### Mosaicing

# %%
# Get meta data on the raster images
# !gdalinfo ~/Documents/PhD_Materials/github_repos/Tadych_PlanetData_Challenge/Data/RapidEye/1354105_2010-03-25_RE5_3A_Analytic_SR_clip.tif
# Out:
# Driver: GTiff/GeoTIFF
# Files: /Users/danielletadych/Documents/PhD_Materials/github_repos/Tadych_PlanetData_Challenge/Data/RapidEye/1354105_2010-03-25_RE5_3A_Analytic_SR_clip.tif
#        /Users/danielletadych/Documents/PhD_Materials/github_repos/Tadych_PlanetData_Challenge/Data/RapidEye/1354105_2010-03-25_RE5_3A_Analytic_SR_clip.tif.aux.xml
# Size is 248, 309
# Coordinate System is:
# PROJCRS["WGS 84 / UTM zone 13N",
#     BASEGEOGCRS["WGS 84",
#         DATUM["World Geodetic System 1984",
#             ELLIPSOID["WGS 84",6378137,298.257223563,
#                 LENGTHUNIT["metre",1]]],
#         PRIMEM["Greenwich",0,
#             ANGLEUNIT["degree",0.0174532925199433]],
#         ID["EPSG",4326]],
#     CONVERSION["UTM zone 13N",
#         METHOD["Transverse Mercator",
#             ID["EPSG",9807]],
#         PARAMETER["Latitude of natural origin",0,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8801]],
#         PARAMETER["Longitude of natural origin",-105,
#             ANGLEUNIT["degree",0.0174532925199433],
#             ID["EPSG",8802]],
#         PARAMETER["Scale factor at natural origin",0.9996,
#             SCALEUNIT["unity",1],
#             ID["EPSG",8805]],
#         PARAMETER["False easting",500000,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8806]],
#         PARAMETER["False northing",0,
#             LENGTHUNIT["metre",1],
#             ID["EPSG",8807]]],
#     CS[Cartesian,2],
#         AXIS["(E)",east,
#             ORDER[1],
#             LENGTHUNIT["metre",1]],
#         AXIS["(N)",north,
#             ORDER[2],
#             LENGTHUNIT["metre",1]],
#     USAGE[
#         SCOPE["Engineering survey, topographic mapping."],
#         AREA["Between 108°W and 102°W, northern hemisphere between equator and 84°N, onshore and offshore. Canada - Northwest Territories (NWT); Nunavut; Saskatchewan. Mexico. United States (USA)."],
#         BBOX[0,-108,84,-102]],
#     ID["EPSG",32613]]
# Data axis to CRS axis mapping: 1,2
# Origin = (283345.000000000000000,3624600.000000000000000)
# Pixel Size = (5.000000000000000,-5.000000000000000)
# Metadata:
#   AREA_OR_POINT=Area
#   TIFFTAG_DATETIME=2010:03:25 18:42:25
#   TIFFTAG_IMAGEDESCRIPTION={"atmospheric_correction": {"aerosol_model": "continental", "aot_coverage": 1.0, "aot_mean_quality": 1, "aot_method": "map", "aot_source": "mod09cma", "aot_status": "Data Found", "aot_std": 0.0394, "aot_used": 0.123, "atmospheric_correction_algorithm": "6Sv2.1", "atmospheric_model": "water_vapor_and_ozone", "luts_version": 3, "ozone_coverage": 1.0, "ozone_mean_quality": 260, "ozone_method": "fixed", "ozone_source": "mod09cmg", "ozone_status": "Data Found", "ozone_std": 0.0012, "ozone_used": 0.32, "satellite_azimuth_angle": 278.99, "satellite_zenith_angle": 7.49, "solar_azimuth_angle": 163.991, "solar_zenith_angle": 31.436, "sr_version": "2.1", "water_vapor_coverage": 1.0, "water_vapor_mean_quality": 1, "water_vapor_method": "fixed", "water_vapor_source": "mod09cma", "water_vapor_status": "Data Found", "water_vapor_std": 0.017, "water_vapor_used": 0.67}}
# Image Structure Metadata:
#   COMPRESSION=LZW
#   INTERLEAVE=BAND
#   PREDICTOR=2
# Corner Coordinates:
# Upper Left  (  283345.000, 3624600.000) (107d18'43.84"W, 32d44'16.57"N)
# Lower Left  (  283345.000, 3623055.000) (107d18'42.55"W, 32d43'26.44"N)
# Upper Right (  284585.000, 3624600.000) (107d17'56.24"W, 32d44'17.44"N)
# Lower Right (  284585.000, 3623055.000) (107d17'54.95"W, 32d43'27.31"N)
# Center      (  283965.000, 3623827.500) (107d18'19.39"W, 32d43'51.94"N)
# Band 1 Block=256x256 Type=UInt16, ColorInterp=Red
#   Min=750.000 Max=1787.000
#   Minimum=750.000, Maximum=1787.000, Mean=1248.792, StdDev=110.677
#   NoData Value=0
#   Metadata:
#     STATISTICS_MAXIMUM=1787
#     STATISTICS_MEAN=1248.7921699149
#     STATISTICS_MINIMUM=750
#     STATISTICS_STDDEV=110.67692951211
#     STATISTICS_VALID_PERCENT=38.03
# Band 2 Block=256x256 Type=UInt16, ColorInterp=Green
#   Min=1049.000 Max=2421.000
#   Minimum=1049.000, Maximum=2421.000, Mean=1670.389, StdDev=148.792
#   NoData Value=0
#   Metadata:
#     STATISTICS_MAXIMUM=2421
#     STATISTICS_MEAN=1670.388999451
#     STATISTICS_MINIMUM=1049
#     STATISTICS_STDDEV=148.79163676264
#     STATISTICS_VALID_PERCENT=38.03
# Band 3 Block=256x256 Type=UInt16, ColorInterp=Blue
#   Min=1508.000 Max=3245.000
#   Minimum=1508.000, Maximum=3245.000, Mean=2163.307, StdDev=223.523
#   NoData Value=0
#   Metadata:
#     STATISTICS_MAXIMUM=3245
#     STATISTICS_MEAN=2163.306992863
#     STATISTICS_MINIMUM=1508
#     STATISTICS_STDDEV=223.52309666755
#     STATISTICS_VALID_PERCENT=38.03
# Band 4 Block=256x256 Type=UInt16, ColorInterp=Undefined
#   NoData Value=0
# Band 5 Block=256x256 Type=UInt16, ColorInterp=Undefined
#   NoData Value=0

# %% [markdown]
# ##### Show all the downloaded Rapid Eye files

# %%
# ls Data/RapidEye/*RE*_3A_Analytic_SR_clip.tif

# %% [markdown]
# ##### Show all the downloaded Planet Scope files

# %%
# ls Data/PlanetScope/*SR_clip.tif

# %%
# for i in years:
#     year = str(i)
#     for j in months:
#         # month = str(j)
#         month = format(j, '02')
#         for k in days:
#             day = format(k, '02')
#             print(year+"-"+month+"-"+day)

# %%
# ls -1 Data/RapidEye/*RE*_3A_Analytic_SR_clip.tif > tiff_test_list.txt

# %%
# items = glob.glob('Data/RapidEye/*2010*RE*_3A_Analytic_SR_clip.tif')
file_loc = 'Data/MES_48R/files/'
items = glob.glob(file_loc+'*SR*.tif')
items
# Out:
# ['Data/MES_48R/files\\1353907_2016-01-11_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-01-24_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-02-04_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-02-10_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-02-15_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-02-28_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-03-02_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-04-10_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-04-30_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-06-06_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-07-09_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2016-07-23_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-01-31_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-02-05_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-02-25_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-03-08_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-03-12_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-04-21_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-05-02_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-05-17_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-05-20_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-06-30_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-09-17_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-09-22_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-10-17_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-10-28_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-11-05_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-11-26_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-11-28_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2017-12-20_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-01-01_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-01-12_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-01-25_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-01-29_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-02-04_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-02-24_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-04-03_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-04-12_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-08-13_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-09-11_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-11-03_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-11-19_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2018-12-19_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-01-01_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-01-24_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-01-26_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-02-08_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-02-16_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-02-17_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-03-22_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-04-08_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-04-20_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-04-23_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-04-28_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-05-09_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-05-21_RE5_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-07-05_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-09-28_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-10-09_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-11-10_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-11-18_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2019-12-29_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2020-01-06_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2020-01-09_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2020-01-11_RE4_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2020-01-25_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2020-02-27_RE3_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2020-03-04_RE1_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1353907_2020-03-07_RE2_3A_Analytic_SR_clip.tif',
#  'Data/MES_48R/files\\1500962_1353907_2018-06-14_0f25_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2109374_1353907_2019-02-11_1002_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2205682_1353907_2019-03-15_106f_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2250369_1353907_2019-04-01_106d_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2268285_1353907_2019-04-08_1061_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2284208_1353907_2019-04-14_106d_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2311483_1353907_2019-04-25_1063_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2322259_1353907_2019-04-29_1062_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2362403_1353907_2019-05-14_1018_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2363207_1353907_2019-05-14_106d_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2397122_1353907_2019-05-27_106e_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\2418032_1353907_2019-06-04_105a_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\3026405_1353907_2020-01-12_100d_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\3070773_1353907_2020-01-25_1004_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\3255674_1353907_2020-03-23_2304_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\
BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\4009610_1353907_2020-12-23_2264_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\4016323_1353907_2020-12-25_225a_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\4020711_1353907_2020-12-27_2424_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\4023740_1353907_2020-12-28_2405_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\519479_1353907_2017-05-26_1002_BGRN_SR_clip.tif',
#  'Data/MES_48R/files\\578225_1353907_2017-06-25_101e_BGRN_SR_clip.tif']

# %%
# Getting the date ranges
years = range(2010,2024)
months = range(1,13)
days = range(0,32)

# Use this to make it stop printing that there aren't images available
gdal.PushErrorHandler('CPLQuietErrorHandler')

# Mosaicing for loop for Both Rapid Eye and PS
for i in years:
    year = str(i)
    for j in months:
        # month = str(j)
        month = format(j, '02')
        for k in days:
            day = format(k, '02')
            # print(year+"-"+month+"-"+day) #Un-comment this if you want to see which days hve errors
            monthly_files_list = glob.glob(file_loc+'*'+year+"-"+month+"-"+day+'*SR*.tif')
            # This code was for writing all the files into a text file
            # with open(year+'-'+month+'_tif_list.txt', 'w') as f:
            #     for line in items:
            #         f.write(line)
            #         f.write('\n')
            files_to_mosaic = monthly_files_list # However many you want.
            g = gdal.Warp('outputfiles/MES_48R/mosaic_'+year+'-'+month+"-"+day+'.tif', files_to_mosaic, format="GTiff",
                  options=["COMPRESS=LZW", "TILED=YES"]) # if you want
            g = None # Close file and flush to disk
            # !gdal_merge.py -n 0 -v -o 'mosaic_year'+'-'+month+'_test.tif' --optfile year+'-'+month+'2010_tif_list.txt'
    print('Finished for ',year)
# Out:
# Finished for  2010
# Finished for  2011
# Finished for  2012
# Finished for  2013
# Finished for  2014
# Finished for  2015
# Finished for  2016
# Finished for  2017
# Finished for  2018
# Finished for  2019
# Finished for  2020
# Finished for  2021
# Finished for  2022
# Finished for  2023

# %%
# Getting the date ranges
years = range(2016,2020)
months = range(1,13)
days = range(0,32)

# Use this to make it stop printing that there aren't images available
gdal.PushErrorHandler('CPLQuietErrorHandler')

# Mosaicing for loop for Rapid Eye
for i in years:
    year = str(i)
    for j in months:
        # month = str(j)
        month = format(j, '02')
        for k in days:
            day = format(k, '02')
            # print(year+"-"+month+"-"+day) #Un-comment this if you want to see which days hve errors
            monthly_files_list = glob.glob('Data/RapidEye/*'+year+"-"+month+"-"+day+'*_3A_Analytic_SR_clip.tif')
            # This code was for writing all the files into a text file
            # with open(year+'-'+month+'_tif_list.txt', 'w') as f:
            #     for line in items:
            #         f.write(line)
            #         f.write('\n')
            files_to_mosaic = monthly_files_list # However many you want.
            g = gdal.Warp('outputfiles/mosaic_'+year+'-'+month+"-"+day+'.tif', files_to_mosaic, format="GTiff",
                  options=["COMPRESS=LZW", "TILED=YES"]) # if you want
            g = None # Close file and flush to disk
            # !gdal_merge.py -n 0 -v -o 'mosaic_year'+'-'+month+'_test.tif' --optfile year+'-'+month+'2010_tif_list.txt'
    print('Finished for ',year)
# Out:
# Finished for  2010
# Finished for  2011
# Finished for  2012
# Finished for  2013
# Finished for  2014
# Finished for  2015
# Finished for  2016
# Finished for  2017

# %%
gdal.PushErrorHandler('CPLQuietErrorHandler')
# Mosaicing for loop for PlanetScope SR
for i in years:
    year = str(i)
    for j in months:
        # month = str(j)
        month = format(j, '02')
        for k in days:
            day = format(k, '02')
            # print(year+"-"+month+"-"+day)
            monthly_files_list = glob.glob('Data/PlanetScope/*'+year+"-"+month+"-"+day+'*RE*_3A_Analytic_SR_clip.tif')
            # This code was for writing all the files into a text file
            # with open(year+'-'+month+'_tif_list.txt', 'w') as f:
            #     for line in items:
            #         f.write(line)
            #         f.write('\n')
            files_to_mosaic = monthly_files_list # However many you want.
            g = gdal.Warp('outputfiles/mosaic_'+year+'-'+month+"-"+day+'.tif', files_to_mosaic, format="GTiff",
                  options=["COMPRESS=LZW", "TILED=YES"]) # if you want
            g = None # Close file and flush to disk
            # !gdal_merge.py -n 0 -v -o 'mosaic_year'+'-'+month+'_test.tif' --optfile year+'-'+month+'2010_tif_list.txt'
    print('finished for ',year)
# Out:
# 2010-01-00
# 2010-01-01
# 2010-01-02
# 2010-01-03
# 2010-01-04
# 2010-01-05
# 2010-01-06
# 2010-01-07
# 2010-01-08
# 2010-01-09
# 2010-01-10
# 2010-01-11
# 2010-01-12
# 2010-01-13
# 2010-01-14
# 2010-01-15
# 2010-01-16
# 2010-01-17
# 2010-01-18
# 2010-01-19
# 2010-01-20
# 2010-01-21
# 2010-01-22
# 2010-01-23
# 2010-01-24
# 2010-01-25
# 2010-01-26
# 2010-01-27
# 2010-01-28
# 2010-01-29
# 2010-01-30
# 2010-01-31
# 2010-02-00
# 2010-02-01
# 2010-02-02
# 2010-02-03
# 2010-02-04
# 2010-02-05
# 2010-02-06
# 2010-02-07
# 2010-02-08
# 2010-02-09
# 2010-02-10
# 2010-02-11
# 2010-02-12
# 2010-02-13
# 2010-02-14
# 2010-02-15
# 2010-02-16
# 2010-02-17
# 2010-02-18
# 2010-02-19
# 2010-02-20
# 2010-02-21
# 2010-02-22
# 2010-02-23
# 2010-02-24
# 2010-02-25
# 2010-02-26
# 2010-02-27
# 2010-02-28
# 2010-02-29
# 2010-02-30
# 2010-02-31
# 2010-03-00
# 2010-03-01
# 2010-03-02
# 2010-03-03
# 2010-03-04
# 2010-03-05
# 2010-03-06
# 2010-03-07
# 2010-03-08
# 2010-03-09
# 2010-03-10
# 2010-03-11
# 2010-03-12
# 2010-03-13
# 2010-03-14
# 2010-03-15
# 2010-03-16
# 2010-03-17
# 2010-03-18
# 2010-03-19
# 2010-03-20
# 2010-03-21
# 2010-03-22
# 2010-03-23
# 2010-03-24
# 2010-03-25
# 2010-03-26
# 2010-03-27
# 2010-03-28
# 2010-03-29
# 2010-03-30
# 2010-03-31
# 2010-04-00
# 2010-04-01
# 2010-04-02
# 2010-04-03
# 2010-04-04
# 2010-04-05
# 2010-04-06
# 2010-04-07
# 2010-04-08
# 2010-04-09
# 2010-04-10
# 2010-04-11
# 2010-04-12
# 2010-04-13
# 2010-04-14
# 2010-04-15
# 2010-04-16
# 2010-04-17
# 2010-04-18
# 2010-04-19
# 2010-04-20
# 2010-04-21
# 2010-04-22
# 2010-04-23
# 2010-04-24
# 2010-04-25
# 2010-04-26
# 2010-04-27
# 2010-04-28
# 2017-11-29
# 2017-11-30
# 2017-11-31
# 2017-12-00
# 2017-12-01
# 2017-12-02
# 2017-12-03
# 2017-12-04
# 2017-12-05
# 2017-12-06
# 2017-12-07
# 2017-12-08
# 2017-12-09
# 2017-12-10
# 2017-12-11
# 2017-12-12
# 2017-12-13
# 2017-12-14
# 2017-12-15
# 2017-12-16
# 2017-12-17
# 2017-12-18
# 2017-12-19
# 2017-12-20
# 2017-12-21
# 2017-12-22
# 2017-12-23
# 2017-12-24
# 2017-12-25
# 2017-12-26
# 2017-12-27
# 2017-12-28
# 2017-12-29
# 2017-12-30
# 2017-12-31
# finished for  2017

# %% [markdown]
# ### Extract the data from the red and near-infrared bands

# %%
import rasterio
import numpy as np

filepath = "outputfiles/MES_48R/"
outputpath = 'outputfiles/ndvi/'
# filename = "data/20160831_180302_0e26_3B_AnalyticMS_SR.tif"
# filename = filepath+"1354107_2013-05-19_RE2_3A_Analytic_SR_clip.tif"
# filename = '2013-05-19_merged.tif'
filename = 'mosaic_2019-03-15.tif'

# Load red and NIR bands - note all PlanetScope 4-band images have band order BGRN
with rasterio.open(filepath+filename) as src:
    band_red = src.read(3)

with rasterio.open(filepath+filename) as src:
    band_nir = src.read(4)

# %% [markdown]
# ### Perform the NDVI calculation

# %% [markdown]
# Next, you're going to calculate NDVI through subtraction and division of the values stored in the NumPy arrays. This calculation will give you NDVI values that range from -1 to 1. Values closer to 1 indicate a greater density of vegetation or higher level of "greenness."

# %%
# Allow division by zero
np.seterr(divide='ignore', invalid='ignore')

# Calculate NDVI. This is the equation at the top of this guide expressed in code
ndvi = (band_nir.astype(float) - band_red.astype(float)) / (band_nir + band_red)

# %%
# check range NDVI values, excluding NaN
np.nanmin(ndvi), np.nanmax(ndvi)
# Out:
# (0.0008835483300936561, 0.49488942575729417)

# %% [markdown]
# ### Save an NDVI image

# %% [markdown]
# Next, you're going to save the calculated NDVI values to a new image file, making sure the new image file has the same geospatial metadata as the original GeoTIFF we downloaded.

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as colors

"""
The NDVI values will range from -1 to 1. You want to use a diverging color scheme to visualize the data,
and you want to center the colorbar at a defined midpoint. The class below allows you to normalize the colorbar.
"""

class MidpointNormalize(colors.Normalize):
    """
    Normalise the colorbar so that diverging bars work there way either side from a prescribed midpoint value)
    e.g. im=ax1.imshow(array, norm=MidpointNormalize(midpoint=0.,vmin=-100, vmax=100))
    Credit: Joe Kington, http://chris35wills.github.io/matplotlib_diverging_colorbar/
    """
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        # I'm ignoring masked values and all kinds of edge cases to make a
        # simple example...
        x, y = [self.vmin, self.midpoint, self.vmax], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(value, x, y), np.isnan(value))


# Set min/max values from NDVI range for image (excluding NAN)
# set midpoint according to how NDVI is interpreted: https://earthobservatory.nasa.gov/Features/MeasuringVegetation/
min=np.nanmin(ndvi)
max=np.nanmax(ndvi)
mid=0.1

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)

# diverging color scheme chosen from https://matplotlib.org/users/colormaps.html
cmap = plt.cm.RdYlGn 

cax = ax.imshow(ndvi, cmap=cmap, clim=(min, max), norm=MidpointNormalize(midpoint=mid,vmin=min, vmax=max))

ax.axis('off')
ax.set_title('Normalized Difference Vegetation Index '+str(filename), fontsize=18, fontweight='bold')

cbar = fig.colorbar(cax, orientation='horizontal', shrink=0.65)

fig.savefig(outputpath+filename+"ndvi-fig.png", dpi=200, bbox_inches='tight', pad_inches=0.7)

plt.show()

# %%
# Set spatial characteristics of the output object to mirror the input
kwargs = src.meta
kwargs.update(
    dtype=rasterio.float32,
    count = 1)

# Write band calculations to a new raster file
with rasterio.open(outputpath+filename+'_ndvi.tif', 'w', **kwargs) as dst:
        dst.write_band(1, ndvi.astype(rasterio.float32))

# %% [markdown]
# Now to perform the calculation for multiple files at once

# %%
items = glob.glob('outputfiles/MES_48R/*.tif')
items.sort()
items
# Out:
# ['outputfiles/MES_48R\\mosaic_2016-01-11.tif',
#  'outputfiles/MES_48R\\mosaic_2016-01-24.tif',
#  'outputfiles/MES_48R\\mosaic_2016-02-04.tif',
#  'outputfiles/MES_48R\\mosaic_2016-02-10.tif',
#  'outputfiles/MES_48R\\mosaic_2016-02-15.tif',
#  'outputfiles/MES_48R\\mosaic_2016-02-28.tif',
#  'outputfiles/MES_48R\\mosaic_2016-03-02.tif',
#  'outputfiles/MES_48R\\mosaic_2016-04-10.tif',
#  'outputfiles/MES_48R\\mosaic_2016-04-30.tif',
#  'outputfiles/MES_48R\\mosaic_2016-06-06.tif',
#  'outputfiles/MES_48R\\mosaic_2016-07-09.tif',
#  'outputfiles/MES_48R\\mosaic_2016-07-23.tif',
#  'outputfiles/MES_48R\\mosaic_2017-01-31.tif',
#  'outputfiles/MES_48R\\mosaic_2017-02-05.tif',
#  'outputfiles/MES_48R\\mosaic_2017-02-25.tif',
#  'outputfiles/MES_48R\\mosaic_2017-03-08.tif',
#  'outputfiles/MES_48R\\mosaic_2017-03-12.tif',
#  'outputfiles/MES_48R\\mosaic_2017-04-21.tif',
#  'outputfiles/MES_48R\\mosaic_2017-05-02.tif',
#  'outputfiles/MES_48R\\mosaic_2017-05-17.tif',
#  'outputfiles/MES_48R\\mosaic_2017-05-20.tif',
#  'outputfiles/MES_48R\\mosaic_2017-05-26.tif',
#  'outputfiles/MES_48R\\mosaic_2017-06-25.tif',
#  'outputfiles/MES_48R\\mosaic_2017-06-30.tif',
#  'outputfiles/MES_48R\\mosaic_2017-09-17.tif',
#  'outputfiles/MES_48R\\mosaic_2017-09-22.tif',
#  'outputfiles/MES_48R\\mosaic_2017-10-17.tif',
#  'outputfiles/MES_48R\\mosaic_2017-10-28.tif',
#  'outputfiles/MES_48R\\mosaic_2017-11-05.tif',
#  'outputfiles/MES_48R\\mosaic_2017-11-26.tif',
#  'outputfiles/MES_48R\\mosaic_2017-11-28.tif',
#  'outputfiles/MES_48R\\mosaic_2017-12-20.tif',
#  'outputfiles/MES_48R\\mosaic_2018-01-01.tif',
#  'outputfiles/MES_48R\\mosaic_2018-01-12.tif',
#  'outputfiles/MES_48R\\mosaic_2018-01-25.tif',
#  'outputfiles/MES_48R\\mosaic_2018-01-29.tif',
#  'outputfiles/MES_48R\\mosaic_2018-02-04.tif',
#  'outputfiles/MES_48R\\mosaic_2018-02-24.tif',
tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-28.tif']

# %%
years = range(2010,2023)
for y in years:
    year = str(y)
    yearcount = glob.glob('outputfiles/MES_48R/*'+year+'*.tif')
    print(year,':',len(yearcount))
# Out:
# 2010 : 0
# 2011 : 0
# 2012 : 0
# 2013 : 0
# 2014 : 0
# 2015 : 0
# 2016 : 12
# 2017 : 20
# 2018 : 14
# 2019 : 28
# 2020 : 84
# 2021 : 0
# 2022 : 0

# %%
# For loop to standardize this

for i in items:
    mosaic = i
    # Load red and NIR bands - note all PlanetScope 4-band images have band order BGRN
    with rasterio.open(mosaic) as src:
        band_red = src.read(3)
    with rasterio.open(mosaic) as src:
        band_nir = src.read(4)
    # Allow division by zero
    np.seterr(divide='ignore', invalid='ignore')
    # Calculate NDVI. This is the equation at the top of this guide expressed in code
    ndvi = (band_nir.astype(float) - band_red.astype(float)) / (band_nir + band_red)# check range NDVI values, excluding NaN
    np.nanmin(ndvi), np.nanmax(ndvi)
    # Set spatial characteristics of the output object to mirror the input
    kwargs = src.meta
    kwargs.update(
        dtype=rasterio.float32,
        count = 1)

    # Write band calculations to a new raster file
    with rasterio.open(mosaic+'_ndvi.tif', 'w', **kwargs) as dst:
            dst.write_band(1, ndvi.astype(rasterio.float32))

print("NDVI files exported.")
# Out:
# C:\Users\det19\AppData\Local\Temp\ipykernel_13604\799235378.py:14: RuntimeWarning: All-NaN slice encountered
#   np.nanmin(ndvi), np.nanmax(ndvi)
# NDVI files exported.

# %% [markdown]
# ### Visualize the NDVI values on the image

# %% [markdown]
# In the last two steps, you'll use [Matplotlib](https://matplotlib.org/) to visualize the NDVI values you calculated for the PlanetScope scene. First you'll view a map of the NDVI values; then you'll generate a histogram of NDVI values.

# %% [markdown]
# ### Generate a histogram of NDVI values

# %%
fig2 = plt.figure(figsize=(10,10))
ax = fig2.add_subplot(111)

plt.title(str(filename)+" NDVI Histogram", fontsize=18, fontweight='bold')
plt.xlabel("NDVI values", fontsize=14)
plt.ylabel("# pixels", fontsize=14)


x = ndvi[~np.isnan(ndvi)]
numBins = 20
ax.hist(x,numBins,color='green',alpha=0.8)

fig2.savefig(outputpath+filename+" ndvi-histogram.png", dpi=200, bbox_inches='tight', pad_inches=0.7)

plt.show()

# %% [markdown]
# ## Creating a time indexed dataframe

# %%
# Read in the Shapefile
filename = "DataChallenge_Mask_Reprojected.shp"
# filepath = os.path.join('Data/Shapefiles/', filename)
filepath = os.path.join('Data/Shapefiles/', filename)
study_areas = gp.read_file(filepath)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: Data/Shapefiles/DataChallenge_Mask_Reprojected.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# c:\Users\det19\Documents\Repositories\Tadych_PlanetData_Challenge\RioGrandeAnalysis_Expanded_JustAnalysis.ipynb Cell 36 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/det19/Documents/Repositories/Tadych_PlanetData_Challenge/RioGrandeAnalysis_Expanded_JustAnalysis.ipynb#Y153sZmlsZQ%3D%3D?line=1'>2</a> filename = "DataChallenge_Mask_Reprojected.shp"
#       <a href='vscode-notebook-cell:/c%3A/Users/det19/Documents/Repositories/Tadych_PlanetData_Challenge/RioGrandeAnalysis_Expanded_JustAnalysis.ipynb#Y153sZmlsZQ%3D%3D?line=2'>3</a> filepath = os.path.join('Data/Shapefiles/', filename)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/det19/Documents/Repositories/Tadych_PlanetData_Challenge/RioGrandeAnalysis_Expanded_JustAnalysis.ipynb#Y153sZmlsZQ%3D%3D?line=3'>4</a> study_areas = gp.read_file(filepath)
#
# File c:\Users\det19\.conda\envs\planet_dc\lib\site-packages\geopandas\io\file.py:201, in _read_file(filename, bbox, mask, rows, **kwargs)
#     198     reader = fiona.open
#     200 with fiona_env():
# --> 201     with reader(path_or_bytes, **kwargs) as features:
#     202
#     203         # In a future Fiona release the crs attribute of features will
#     204         # no longer be a dict, but will behave like a dict. So this should
#     205         # be forwards compatible
#     206         crs = (
#     207             features.crs["init"]
#     208             if features.crs and "init" in features.crs
#     209             else features.crs_wkt
#     210         )
#     212         # handle loading the bounding box
#
# File c:\Users\det19\.conda\envs\planet_dc\lib\site-packages\fiona\env.py:408, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwargs)
#     405 @wraps(f)
#     406 def wrapper(*args, **kwargs):
#     407     if local._env:
# --> 408         return f(*args, **kwargs)
#     409     else:
#     410         if isinstance(args[0], str):
#
# File c:\Users\det19\.conda\envs\planet_dc\lib\site-packages\fiona\__init__.py:264, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, **kwargs)
#     261     path = parse_path(fp)
#     263 if mode in ('a', 'r'):
# --> 264     c = Collection(path, mode, driver=driver, encoding=encoding,
#     265                    layer=layer, enabled_drivers=enabled_drivers, **kwargs)
#     266 elif mode == 'w':
#     267     if schema:
#     268         # Make an ordered dict of schema properties.
#
# File c:\Users\det19\.conda\envs\planet_dc\lib\site-packages\fiona\collection.py:162, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, **kwargs)
#     160 if self.mode == 'r':
#     161     self.session = Session()
# --> 162     self.session.start(self, **kwargs)
#     163 elif self.mode in ('a', 'w'):
#     164     self.session = WritingSession()
#
# File fiona/ogrext.pyx:540, in fiona.ogrext.Session.start()
#
# File fiona/_shim.pyx:90, in fiona._shim.gdal_open_vector()
#
# DriverError: Data/Shapefiles/DataChallenge_Mask_Reprojected.shp: No such file or directory

# %%
date_list = []
for i in items:
    date = i[-14:-4]
    parsed_date = datetime.datetime.strptime(date, "%Y-%m-%d")
    date_list.append(parsed_date)
dt_array = np.array(date_list, dtype='datetime64')
dt_array.sort()

# %%
dt_array
# Out:
# array(['2016-01-11T00:00:00.000000', '2016-01-24T00:00:00.000000',
#        '2016-02-04T00:00:00.000000', '2016-02-10T00:00:00.000000',
#        '2016-02-15T00:00:00.000000', '2016-02-28T00:00:00.000000',
#        '2016-03-02T00:00:00.000000', '2016-04-10T00:00:00.000000',
#        '2016-04-30T00:00:00.000000', '2016-06-06T00:00:00.000000',
#        '2016-07-09T00:00:00.000000', '2016-07-23T00:00:00.000000',
#        '2017-01-31T00:00:00.000000', '2017-02-05T00:00:00.000000',
#        '2017-02-25T00:00:00.000000', '2017-03-08T00:00:00.000000',
#        '2017-03-12T00:00:00.000000', '2017-04-21T00:00:00.000000',
#        '2017-05-02T00:00:00.000000', '2017-05-17T00:00:00.000000',
#        '2017-05-20T00:00:00.000000', '2017-05-26T00:00:00.000000',
#        '2017-06-25T00:00:00.000000', '2017-06-30T00:00:00.000000',
#        '2017-09-17T00:00:00.000000', '2017-09-22T00:00:00.000000',
#        '2017-10-17T00:00:00.000000', '2017-10-28T00:00:00.000000',
#        '2017-11-05T00:00:00.000000', '2017-11-26T00:00:00.000000',
tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-08-22.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-08-23.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-08-27.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-09-01.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-09-05.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-09-08.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-09-11.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-09-17.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-09-25.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-09-29.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-01.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-03.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-07.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-08.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-09.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-10.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-14.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-19.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-20.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-22.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-23.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-25.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-26.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-10-29.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-11.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-13.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-15.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-16.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-17.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-18.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-20.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-23.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-25.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-27.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-11-29.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-01.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-03.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-06.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-07.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-11.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-14.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-15.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-16.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-17.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-19.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-21.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-23.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-25.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-27.tif_ndvi.tif',
#  'outputfiles/MES_48R\\mosaic_2020-12-28.tif_ndvi.tif']

# %%
# Testing to see if coordinate systems match
ndvi_file_toclip = xr.open_dataset(ndvi_tifs[17])
# mask = study_areas
# print("mask crs:", mask.crs)
print("data crs:", ndvi_file_toclip.rio.crs)
# Out:
# data crs: EPSG:32613

# %%
# Skip this if they are both in the same coordinate system and change info in next cell
mask_reproject = mask.to_crs(epsg=32613)
print("mask crs:", mask_reproject.crs)
# Out:
# mask crs: EPSG:32613

# %%
# Clipping
clipped = ndvi_file_toclip.rio.clip(mask_reproject.geometry, mask_reproject.crs)
# clipped.plot()

# %%
clipped_np = clipped['band_data'].to_numpy()
clipped_np.shape
# Out:
# (1, 3160, 4990)

# %%
ndvi_file_1 = xr.open_dataset(ndvi_tifs[0])
# ndvi_file['band_data']
ndvi_data_1 = ndvi_file_1['band_data']
ndvi_array_1 = ndvi_data_1.to_numpy()
ndvi_array_1.shape
# Out:
# (1, 483, 196)

# %%
ndvi_file_2 = xr.open_dataset(ndvi_tifs[100])
# ndvi_file['band_data']
ndvi_data_2 = ndvi_file_1['band_data']
ndvi_array_2 = ndvi_data_1.to_numpy()
ndvi_array_2.shape
# Out:
# (1, 483, 196)

# %%
for i in ndvi_tifs
# Out:
# 158

# %%
all_data = []
for i in ndvi_tifs:
    print(i)
    ndvi_file = xr.open_dataset(i)
    # clipped = ndvi_file.rio.clip(mask_reproject.geometry, mask_reproject.crs)
    # ndvi_data = clipped['band_data']
    ndvi_data = ndvi_file['band_data']
    ndvi_array = ndvi_data.to_numpy()
    # # dummy_array = np.ndarray(shape=ndvi_array_1,dtype=float)
    # # ndvi_array.read.direct(dummy_array)
    # # np.place(dummy_array, dummy_array==ndvi_array.attrs.get('_FillValue'),np.nan)
    # ndvi_array=np.ndarray(shape=ndvi_data.shape,dtype=float)
    # ndvi_data.read_direct(ndvi_array)
    # np.place(ndvi_array,ndvi_array==ndvi_data.attrs.get('_FillValue'), np.nan)
    all_data.append(ndvi_array)
    print(ndvi_array.shape)
    # all_data.append(ndvi_file)
# all_data
# Out:
# outputfiles/MES_48R\mosaic_2016-01-11.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-01-24.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-02-04.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-02-10.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-02-15.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-02-28.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-03-02.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-04-10.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-04-30.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-06-06.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-07-09.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2016-07-23.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-01-31.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-02-05.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-02-25.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-03-08.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-03-12.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-04-21.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-05-02.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-05-17.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-05-20.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-05-26.tif_ndvi.tif
# (1, 772, 313)
# outputfiles/MES_48R\mosaic_2017-06-25.tif_ndvi.tif
# (1, 772, 313)
# outputfiles/MES_48R\mosaic_2017-06-30.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-09-17.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-09-22.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-10-17.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-10-28.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-11-05.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-11-26.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-11-28.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2017-12-20.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2018-01-01.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2018-01-12.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2018-01-25.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2018-01-29.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2018-02-04.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2018-02-24.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2018-04-03.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2018-04-12.tif_ndvi.tif
# (1, 483, 196)
# outputfiles/MES_48R\mosaic_2018
...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ..., 0.12614259,
#          0.10476191, 0.04962153],
#         [       nan,        nan,        nan, ..., 0.11536748,
#          0.08584905, 0.05160744],
#         [       nan,        nan,        nan, ..., 0.09662751,
#          0.12414109, 0.07085916]],
#
#        [[0.21866295, 0.2521861 , 0.20318726, ...,        nan,
#                 nan,        nan],
#         [0.18223584, 0.20993087, 0.17650676, ...,        nan,
#                 nan,        nan],
#         [0.14185022, 0.16591929, 0.16630669, ...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ..., 0.38183933,
#          0.30962098, 0.18342541],
#         [       nan,        nan,        nan, ..., 0.36550194,
#          0.30046403, 0.17309813],
#         [       nan,        nan,        nan, ..., 0.35623267,
#          0.37254903, 0.26174498]],
#
#        [[0.09474347, 0.07906388, 0.05541347, ...,        nan,
#                 nan,        nan],
#         [0.07868556, 0.05228951, 0.05616183, ...,        nan,
#                 nan,        nan],
#         [0.07407407, 0.05018687, 0.04616144, ...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ..., 0.12383178,
#          0.12618296, 0.12377711],
#         [       nan,        nan,        nan, ..., 0.11785533,
#          0.11302585, 0.06386555],
#         [       nan,        nan,        nan, ..., 0.11089589,
#          0.12154408, 0.08402585]],
#
#        ...,
#
#        [[0.14802982, 0.1309131 , 0.16142705, ...,        nan,
#                 nan,        nan],
#         [0.11321349, 0.08457711, 0.12443946, ...,        nan,
#                 nan,        nan],
#         [0.11016226, 0.104708  , 0.09722558, ...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ..., 0.248671  ,
#          0.15045089, 0.04468865],
#         [       nan,        nan,        nan, ..., 0.28747568,
#          0.15397082, 0.10533275],
#         [       nan,        nan,        nan, ..., 0.3745401 ,
#          0.2983871 , 0.21292374]],
#
#        [[0.14582501, 0.08431897, 0.04245133, ...,        nan,
#                 nan,        nan],
#         [0.05926623, 0.13429952, 0.10467706, ...,        nan,
#                 nan,        nan],
#         [0.07970008, 0.11163896, 0.08440959, ...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ..., 0.19244823,
#          0.09968521, 0.01830443],
#         [       nan,        nan,        nan, ..., 0.28103682,
#          0.16470589, 0.07775965],
#         [       nan,        nan,        nan, ..., 0.2570481 ,
#          0.11673469, 0.08883554]],
#
#        [[0.13654473, 0.10951526, 0.05664264, ...,        nan,
#                 nan,        nan],
#         [0.06841612, 0.08756039, 0.07059477, ...,        nan,
#                 nan,        nan],
#         [0.03472222, 0.07624795, 0.07847478, ...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ..., 0.25353926,
#          0.17713568, 0.08290452],
#         [       nan,        nan,        nan, ..., 0.24761905,
#          0.21157822, 0.16733068],
#         [       nan,        nan,        nan, ..., 0.29340512,
#          0.2766252 , 0.24931507]]], dtype=float32)

# %%
lat_main = clipped['x']
lon_main = clipped['y']

lon_main = lon_main.to_numpy()
lat_main = lat_main.to_numpy()
# lat_main

# %%
print("Main data shape: ", combo.shape)
print('Longitude shape: ', lon_main.shape)
print("Latitude shape: ", lat_main.shape)
print('Data Shape: ', dt_array.shape)
# Out:
# Main data shape:  (30, 3160, 4990)
# Longitude shape:  (3160,)
# Latitude shape:  (4990,)
# Data Shape:  (30,)

# %%
data_xr = xr.DataArray(
    combo,
    coords={'time':dt_array,'lon': lon_main,'lat': lat_main}, 
    dims=["time","lon", "lat"],
    attrs=dict(
        description="Calculated NDVI")
)
data_xr
# Out:
# <xarray.DataArray (time: 30, lon: 3160, lat: 4990)>
# array([[[0.06839687, 0.07827039, 0.07583418, ...,        nan,
#                 nan,        nan],
#         [0.07864597, 0.05376344, 0.06229661, ...,        nan,
#                 nan,        nan],
#         [0.04583439, 0.01787394, 0.05179795, ...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ..., 0.12614259,
#          0.10476191, 0.04962153],
#         [       nan,        nan,        nan, ..., 0.11536748,
#          0.08584905, 0.05160744],
#         [       nan,        nan,        nan, ..., 0.09662751,
#          0.12414109, 0.07085916]],
#
#        [[0.21866295, 0.2521861 , 0.20318726, ...,        nan,
#                 nan,        nan],
#         [0.18223584, 0.20993087, 0.17650676, ...,        nan,
#                 nan,        nan],
#         [0.14185022, 0.16591929, 0.16630669, ...,        nan,
#                 nan,        nan],
# ...
#         [       nan,        nan,        nan, ..., 0.19244823,
#          0.09968521, 0.01830443],
#         [       nan,        nan,        nan, ..., 0.28103682,
#          0.16470589, 0.07775965],
#         [       nan,        nan,        nan, ..., 0.2570481 ,
#          0.11673469, 0.08883554]],
#
#        [[0.13654473, 0.10951526, 0.05664264, ...,        nan,
#                 nan,        nan],
#         [0.06841612, 0.08756039, 0.07059477, ...,        nan,
#                 nan,        nan],
#         [0.03472222, 0.07624795, 0.07847478, ...,        nan,
#                 nan,        nan],
#         ...,
#         [       nan,        nan,        nan, ..., 0.25353926,
#          0.17713568, 0.08290452],
#         [       nan,        nan,        nan, ..., 0.24761905,
#          0.21157822, 0.16733068],
#         [       nan,        nan,        nan, ..., 0.29340512,
#          0.2766252 , 0.24931507]]], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2010-03-25 2010-10-27 ... 2017-11-10
#   * lon      (lon) float64 3.627e+06 3.627e+06 3.627e+06 ... 3.611e+06 3.611e+06
#   * lat      (lat) float64 2.854e+05 2.854e+05 2.854e+05 ... 3.104e+05 3.104e+05
# Attributes:
#     description:  Calculated NDVI

# %%
data_xr2 = data_xr.rio.set_spatial_dims('lat','lon')
data_xr2.rio.to_raster(r"NDVI_time_attempt2.nc")

# %%
data_xr2[0,:,:].plot()

# %% [markdown]
# ## Timeseries

# %%
# Study area mean
NDVI_ts = data_xr2.mean(('lon','lat'))
NDVI_ts.plot()

# %%
NDVI_ts_df = NDVI_ts.to_dataframe(name='NDVI')
NDVI_ts_df['Year'] = pd.DatetimeIndex(NDVI_ts_df.index).year
NDVI_ts_df
# Out:
#                 NDVI  Year
# time
# 2010-03-25  0.045241  2010
# 2010-10-27  0.180760  2010
# 2010-12-09  0.068149  2010
# 2012-02-15  0.062190  2012
# 2012-10-17  0.114276  2012
# 2013-01-13  0.059894  2013
# 2013-02-01  0.054340  2013
# 2013-05-19  0.080961  2013
# 2013-05-20  0.088244  2013
# 2013-10-03  0.150722  2013
# 2013-11-02  0.107308  2013
# 2013-12-01  0.052648  2013
# 2013-12-17  0.054423  2013
# 2014-01-03  0.070468  2014
# 2014-03-21  0.050059  2014
# 2014-03-22  0.058936  2014
# 2014-07-26  0.075831  2014
# 2014-10-12  0.144066  2014
# 2015-04-14  0.077225  2015
# 2016-01-11  0.089095  2016
# 2016-02-04  0.087477  2016
# 2016-04-14  0.065878  2016
# 2016-06-10  0.075915  2016
# 2016-06-14  0.081862  2016
# 2017-01-04  0.055315  2017
# 2017-02-23  0.073782  2017
# 2017-05-20  0.096551  2017
# 2017-10-08  0.118029  2017
# 2017-10-25  0.103093  2017
# 2017-11-10  0.089606  2017

# %%
f, ax = plt.subplots(figsize=(12,6))
# ax.scatter(NDVI_ts.index, NDVI_ts[0], color='red')
ax.scatter(NDVI_ts_df.index, NDVI_ts_df['NDVI'], c='green')
# ax.axvspan("2017-06-10T12:00:00.000Z", "2018-06-16T00:00:00.000Z", color='grey', alpha=0.5, lw=0, label="Satellite relaunch gap")
ax.set(title="NDVI Values for the Rio Grande over time")
ax.legend(loc = 'upper right')
ax.grid(zorder = 0)
plt.xlabel('Year')
plt.ylabel('NDVI (-1 to 1)')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Text(0, 0.5, 'NDVI (-1 to 1)')

# %%
# Reading in KC's data
seepage = pd.read_csv('Data/From_KC/Flow_values.csv')
seepage
# Out:
#    Monitoring station  Rin_10R  Rin_1R  Rin_11R  Rin_9R  Rin_2R  Rin_8R  \
# 0              2010.0    0.040   0.016    0.021  -0.001   0.001   0.035
# 1              2011.0    0.054   0.039    0.061   0.059   0.046   0.049
# 2              2012.0    0.101   0.089    0.113   0.113   0.113   0.061
# 3              2013.0    0.058   0.064    0.098   0.113   0.080   0.045
# 4              2014.0    0.074   0.087    0.113   0.113   0.097   0.063
# 5              2015.0    0.050   0.055    0.088   0.109   0.056   0.036
# 6              2016.0    0.092   0.099    0.113   0.113   0.095   0.056
# 7              2017.0    0.052   0.045    0.065   0.089   0.042   0.020
# 8                 NaN      NaN     NaN      NaN     NaN     NaN     NaN
#
#    Rin_3R  Rin_7R  Rin_4R  Rin_5R  Rin_12R  Rin_6R  Rin_13R   Mean    Sum  \
# 0   0.020   0.030   0.014   0.019    0.003  -0.018    0.000  0.012  0.141
# 1   0.044   0.050   0.035   0.024    0.033   0.007    0.004  0.038  0.451
# 2   0.096   0.082   0.081   0.056    0.074   0.035    0.031  0.079  0.944
# 3   0.063   0.053   0.058   0.042    0.072   0.016    0.034  0.061  0.737
# 4   0.093   0.075   0.090   0.061    0.113   0.024    0.042  0.081  0.972
# 5   0.063   0.045   0.060   0.037    0.083   0.014    0.025  0.056  0.672
# 6   0.096   0.067   0.091   0.062    0.082   0.012    0.048  0.078  0.935
# 7   0.034   0.053   0.044   0.035    0.011  -0.016    0.027  0.037  0.449
# 8     NaN     NaN     NaN     NaN      NaN     NaN      NaN    NaN    NaN
#
#    Std dev
# 0    0.014
# 1    0.018
# 2    0.027
# 3    0.026
# 4    0.028
# 5    0.026
# 6    0.029
# 7    0.025
# 8      NaN

# %%
head = pd.read_csv('Data/From_KC/Groundwater_head_values.csv')
head
# Out:
#    Monitoring station  Rin_10R  Rin_1R  Rin_11R  Rin_9R  Rin_2R  Rin_8R  \
# 0                2010    0.859   1.015    1.772   0.771   1.101   1.003
# 1                2011    0.466   0.548    0.982  -0.289   0.287   0.620
# 2                2012    0.139   0.109    0.181  -0.341  -0.341   0.722
# 3                2013    0.095  -0.223   -0.178  -0.341  -0.341   0.470
# 4                2014    0.017  -0.341   -0.341  -0.341  -0.341   0.296
# 5                2015    0.132  -0.181   -0.199  -0.341  -0.317   0.558
# 6                2016    0.364   0.104    0.543  -0.341   0.019   0.855
# 7                2017    0.694   0.604    1.166  -0.341   0.533   1.223
#
#    Rin_3R  Rin_7R  Rin_4R  Rin_5R  Rin_12R  Rin_6R  Rin_13R   Mean     Sum  \
# 0   1.242   1.366   1.803   1.621    2.548   2.345    2.014  1.550  18.601
# 1   0.751   0.897   1.380   1.465    2.005   1.967    1.948  1.047  12.559
# 2   0.300   0.753   0.970   1.177    1.647   1.642    1.616  0.703   8.434
# 3   0.085   0.587   0.684   0.936    0.941   1.706    1.228  0.463   5.554
# 4  -0.248   0.357   0.280   0.727   -0.026   1.623    1.213  0.238   2.857
# 5  -0.105   0.648   0.454   0.936    0.440   1.729    1.365  0.416   4.987
# 6   0.422   1.022   0.960   1.184    1.645   1.948    1.458  0.818   9.818
# 7   1.055   1.055   1.385   1.402    2.440   2.305    1.630  1.205  14.458
#
#    Std dev
# 0    0.539
# 1    0.693
# 2    0.699
# 3    0.643
# 4    0.631
# 5    0.651
# 6    0.664
# 7    0.721

# %%
# Case study stations
seepage_studyareas = seepage[['Monitoring station','Rin_11R','Rin_2R','Rin_12R']]

head_studyareas = head[['Monitoring station','Rin_11R','Rin_2R','Rin_12R']]
head_studyareas
# Out:
#    Monitoring station  Rin_11R  Rin_2R  Rin_12R
# 0                2010    1.772   1.101    2.548
# 1                2011    0.982   0.287    2.005
# 2                2012    0.181  -0.341    1.647
# 3                2013   -0.178  -0.341    0.941
# 4                2014   -0.341  -0.341   -0.026
# 5                2015   -0.199  -0.317    0.440
# 6                2016    0.543   0.019    1.645
# 7                2017    1.166   0.533    2.440

# %%
seepage_studyareas = seepage_studyareas.rename(columns= {'Monitoring station':'Year'})
head_studyareas = head_studyareas.rename(columns= {'Monitoring station':'Year'})
seepage_studyareas = seepage_studyareas.set_index('Year')
head_studyareas = head_studyareas.set_index('Year')
head_studyareas
# Out:
#       Rin_11R  Rin_2R  Rin_12R
# Year
# 2010    1.772   1.101    2.548
# 2011    0.982   0.287    2.005
# 2012    0.181  -0.341    1.647
# 2013   -0.178  -0.341    0.941
# 2014   -0.341  -0.341   -0.026
# 2015   -0.199  -0.317    0.440
# 2016    0.543   0.019    1.645
# 2017    1.166   0.533    2.440

# %%
# NDVI_ts_df = NDVI_ts_df.set_index('Year')
NDVI_ts_df
NDVI_df_year_min = pd.pivot_table(NDVI_ts_df, index=["Year"], values=['NDVI'], dropna=False, aggfunc=np.min)
NDVI_df_year_max = pd.pivot_table(NDVI_ts_df, index=["Year"], values=['NDVI'], dropna=False, aggfunc=np.max)
NDVI_df_year_mean = pd.pivot_table(NDVI_ts_df, index=["Year"], values=['NDVI'], dropna=False, aggfunc=np.mean)

NDVI_df_year_max
# Out:
#           NDVI
# Year
# 2010  0.180760
# 2012  0.114276
# 2013  0.150722
# 2014  0.144066
# 2015  0.077225
# 2016  0.089095
# 2017  0.118029

# %%
f, ax = plt.subplots(figsize=(12,6))
# ax.scatter(NDVI_ts.index, NDVI_ts[0], color='red')
ax2 = ax.twinx()
ax2.scatter(head_studyareas.index, head_studyareas['Rin_11R'], c='blue', label = 'Pressure Head Range')
ax2.scatter(head_studyareas.index, head_studyareas['Rin_2R'], c='blue')
ax2.scatter(head_studyareas.index, head_studyareas['Rin_12R'], c='blue')
ax.scatter(NDVI_df_year_max.index, NDVI_df_year_max['NDVI'], c='green',label = 'NDVI Range')
ax.scatter(NDVI_df_year_min.index, NDVI_df_year_min['NDVI'], c='green')
ax2.hlines(y=2.0, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
ax2.hlines(y=0, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
ax2.hlines(y=0.325, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
ax.text(2016.5, 0.156, 'Connected ^Losing', style='italic', bbox={
        'facecolor': 'white', 'alpha': 0, 'pad': 5})
ax.text(2016.5, 0.150, 'Connected v Gaining', style='italic', bbox={
        'facecolor': 'white', 'alpha': 0, 'pad': 5})
ax.text(2016.5, 0.078, 'Transition', style='oblique', bbox={
        'facecolor': 'white', 'alpha': 0.0, 'pad': 5})
ax.text(2016.5, 0.063, 'Disconnected', style='oblique', bbox={
        'facecolor': 'white', 'alpha': 0, 'pad': 5})
ax.set(title="NDVI vs. Head Values at the Rio Grande over time")
ax.legend(loc = [0,0.86])
ax2.legend(loc = [0,0.8])
ax.grid(zorder = 0)
ax.set_xlabel('Year')
ax.set_ylabel('NDVI (-1 to 1)')
ax2.set_ylabel('Net Annual Pressure Head (m)')
# Out:
# Text(0, 0.5, 'Net Annual Pressure Head (m)')

# %%
f, ax = plt.subplots(figsize=(12,6))
# ax.scatter(NDVI_ts.index, NDVI_ts[0], color='red')
ax2 = ax.twinx()
ax2.scatter(seepage_studyareas.index, seepage_studyareas['Rin_11R'], c='purple', label = 'Seepage Range (cms)')
ax2.scatter(seepage_studyareas.index, seepage_studyareas['Rin_2R'], c='purple')
ax2.scatter(seepage_studyareas.index, seepage_studyareas['Rin_12R'], c='purple')
ax.scatter(NDVI_df_year_max.index, NDVI_df_year_max['NDVI'], c='green',label = 'NDVI Range')
ax.scatter(NDVI_df_year_min.index, NDVI_df_year_min['NDVI'], c='green')
ax2.hlines(y=0.113, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
ax2.hlines(y=0, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
ax2.hlines(y=0.0914, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
ax.text(2016.5, 0.047, 'Connected ^Losing', style='italic', bbox={
        'facecolor': 'white', 'alpha': 0, 'pad': 5})
ax.text(2016.5, 0.156, 'Transition', style='oblique', bbox={
        'facecolor': 'white', 'alpha': 0.0, 'pad': 5})
ax.text(2016.5, 0.182, 'Disconnected', style='oblique', bbox={
        'facecolor': 'white', 'alpha': 0, 'pad': 5})
# ax.axvspan("2017-06-10T12:00:00.000Z", "2018-06-16T00:00:00.000Z", color='grey', alpha=0.5, lw=0, label="Satellite relaunch gap")
ax.set(title="NDVI vs. Seepage Flow Values at the Rio Grande over time")
ax.legend(loc = [0,0.86])
ax2.legend(loc = [0,0.8])
ax.grid(zorder = 0)
ax.set_xlabel('Year')
ax.set_ylabel('NDVI (-1 to 1)')
ax2.set_ylabel('Seepage Flow (cms)')
# Out:
# Text(0, 0.5, 'Seepage Flow (cms)')

# %%
NDVI_DF2 = NDVI_df_year_mean.reset_index()
# NDVI_DF2 = NDVI_DF2.append([2011,np.nan])

df = NDVI_DF2.append({'Year':2011, 'NDVI':np.nan}, ignore_index=True)
df
# Out:
# /var/folders/7k/m9jgv50j0qv046r7xmwxt0qh0000gn/T/ipykernel_3184/3983479622.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = NDVI_DF2.append({'Year':2011, 'NDVI':np.nan}, ignore_index=True)
#      Year      NDVI
# 0  2010.0  0.098050
# 1  2012.0  0.088233
# 2  2013.0  0.081068
# 3  2014.0  0.079872
# 4  2015.0  0.077225
# 5  2016.0  0.080045
# 6  2017.0  0.089396
# 7  2011.0       NaN

# %%
f, ax = plt.subplots(figsize=(10,6))
# ax.scatter(NDVI_ts.index, NDVI_ts[0], color='red')
ax.scatter(df['NDVI'].values, head_studyareas['Rin_11R'].values, c='black',label = 'NDVI Range')
ax.scatter(df['NDVI'].values, head_studyareas['Rin_2R'].values, c='black',label = 'NDVI Range')
ax.scatter(df['NDVI'].values, head_studyareas['Rin_12R'].values, c='black',label = 'NDVI Range')
# ax2.hlines(y=0.113, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
# ax2.hlines(y=0, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
# ax2.hlines(y=0.0915, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
# ax.axvspan("2017-06-10T12:00:00.000Z", "2018-06-16T00:00:00.000Z", color='grey', alpha=0.5, lw=0, label="Satellite relaunch gap")
ax.set(title="NDVI vs. Head Values at the Rio Grande")
# ax.legend(loc = 'lower left')
ax.grid(zorder = 0)
ax.set_ylabel('Net Annual Pressure Head (m)')
ax.set_xlabel('NDVI (-1 to 1)')
# Out:
# Text(0.5, 0, 'NDVI (-1 to 1)')

# %%
# y = seepage_studyareas['Rin_11R'].values
y = seepage_studyareas.iloc[:-1,:]
y
# Out:
#         Rin_11R  Rin_2R  Rin_12R
# Year
# 2010.0    0.021   0.001    0.003
# 2011.0    0.061   0.046    0.033
# 2012.0    0.113   0.113    0.074
# 2013.0    0.098   0.080    0.072
# 2014.0    0.113   0.097    0.113
# 2015.0    0.088   0.056    0.083
# 2016.0    0.113   0.095    0.082
# 2017.0    0.065   0.042    0.011

# %%
f, ax = plt.subplots(figsize=(10,6))
# ax.scatter(NDVI_ts.index, NDVI_ts[0], color='red')
ax.scatter(df['NDVI'].values, y['Rin_11R'].values, c='black',label = 'NDVI Range')
ax.scatter(df['NDVI'].values, y['Rin_2R'].values, c='black',label = 'NDVI Range')
ax.scatter(df['NDVI'].values, y['Rin_12R'].values, c='black',label = 'NDVI Range')
# ax2.hlines(y=0.113, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
# ax2.hlines(y=0, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
# ax2.hlines(y=0.0915, xmin = 2009.5, xmax = 2017.5,color='grey',linestyles='--')
# ax.axvspan("2017-06-10T12:00:00.000Z", "2018-06-16T00:00:00.000Z", color='grey', alpha=0.5, lw=0, label="Satellite relaunch gap")
ax.set(title="NDVI vs. Seepage Flow Values at the Rio Grande")
# ax.legend(loc = 'lower left')
ax.grid(zorder = 0)
ax.set_ylabel('Seepage Flow (cms)')
ax.set_xlabel('NDVI (-1 to 1)')
# Out:
# Text(0.5, 0, 'NDVI (-1 to 1)')

# %% [markdown]
# Failed Code

# %%
ndvi3 = data2.transpose('time', 'lat', 'lon')
# ndvi3 = data2
# ndvi3 = ndvi.rio.set_crs("epsg:4326")

ndvi3.rio.set_spatial_dims('lon', 'lat')
# Out:
# <xarray.DataArray 'NDVI' (time: 30, lat: 4990, lon: 3160)>
# array([[[       nan,        nan,        nan, ..., 0.04583439,
#          0.07864597, 0.06839687],
#         [       nan,        nan,        nan, ..., 0.01787394,
#          0.05376344, 0.07827039],
#         [       nan,        nan,        nan, ..., 0.05179795,
#          0.06229661, 0.07583418],
#         ...,
#         [0.09662751, 0.11536748, 0.12614259, ...,        nan,
#                 nan,        nan],
#         [0.12414109, 0.08584905, 0.10476191, ...,        nan,
#                 nan,        nan],
#         [0.07085916, 0.05160744, 0.04962153, ...,        nan,
#                 nan,        nan]],
#
#        [[       nan,        nan,        nan, ..., 0.14185022,
#          0.18223584, 0.21866295],
#         [       nan,        nan,        nan, ..., 0.16591929,
#          0.20993087, 0.2521861 ],
#         [       nan,        nan,        nan, ..., 0.16630669,
#          0.17650676, 0.20318726],
# ...
#         [0.2570481 , 0.28103682, 0.19244823, ...,        nan,
#                 nan,        nan],
#         [0.11673469, 0.16470589, 0.09968521, ...,        nan,
#                 nan,        nan],
#         [0.08883554, 0.07775965, 0.01830443, ...,        nan,
#                 nan,        nan]],
#
#        [[       nan,        nan,        nan, ..., 0.03472222,
#          0.06841612, 0.13654473],
#         [       nan,        nan,        nan, ..., 0.07624795,
#          0.08756039, 0.10951526],
#         [       nan,        nan,        nan, ..., 0.07847478,
#          0.07059477, 0.05664264],
#         ...,
#         [0.29340512, 0.24761905, 0.25353926, ...,        nan,
#                 nan,        nan],
#         [0.2766252 , 0.21157822, 0.17713568, ...,        nan,
#                 nan,        nan],
#         [0.24931507, 0.16733068, 0.08290452, ...,        nan,
#                 nan,        nan]]], dtype=float32)
# Coordinates:
#   * time     (time) datetime64[ns] 2010-03-25 2010-10-27 ... 2017-11-10
#   * lon      (lon) float64 3.611e+06 3.611e+06 3.611e+06 ... 3.627e+06 3.627e+06
#   * lat      (lat) float64 2.854e+05 2.854e+05 2.854e+05 ... 3.104e+05 3.104e+05
# Attributes:
#     description:  Calculated NDVI

# %%
# Write an nc file for remapping
ndvi3.rio.to_raster(r"NDVI_time.nc")
# ndvi3.rio.to_raster(r"NDVI_time.tif")
# ndvi3.to_netcdf()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Write an nc file for remapping
# ----> 2 ndvi3.rio.to_raster(r"NDVI_time_attempt2.nc")
#       3 # ndvi3.rio.to_raster(r"NDVI_time.tif")
#       4 # ndvi3.to_netcdf()
#
# File ~/opt/miniconda3/envs/planet/lib/python3.8/site-packages/rioxarray/raster_array.py:1146, in RasterArray.to_raster(self, raster_path, driver, dtype, tags, windowed, recalc_transform, lock, compute, **profile_kwargs)
#    1127 out_profile = {
#    1128     key: value
#    1129     for key, value in out_profile.items()
#    (...)
#    1140     )
#    1141 }
#    1142 rio_nodata = (
#    1143     self.encoded_nodata if self.encoded_nodata is not None else self.nodata
#    1144 )
# -> 1146 return RasterioWriter(raster_path=raster_path).to_raster(
#    1147     xarray_dataarray=self._obj,
#    1148     tags=tags,
#    1149     driver=driver,
#    1150     height=int(self.height),
#    1151     width=int(self.width),
#    1152     count=int(self.count),
#    1153     dtype=dtype,
#    1154     crs=self.crs,
#    1155     transform=self.transform(recalc=recalc_transform),
#    1156     gcps=self.get_gcps(),
#    1157     nodata=rio_nodata,
#    1158     windowed=windowed,
#    1159     lock=lock,
#    1160     compute=compute,
#    1161     **out_profile,
#    1162 )
#
# File ~/opt/miniconda3/envs/planet/lib/python3.8/site-packages/rioxarray/raster_writer.py:292, in RasterioWriter.to_raster(self, xarray_dataarray, tags, windowed, lock, compute, **kwargs)
#     290                 rds.write(data, 1, window=window)
#     291             else:
# --> 292                 rds.write(data, window=window)
#     294 if lock and is_dask_collection(xarray_dataarray.data):
#     295     return dask.array.store(
#     296         encode_cf_variable(xarray_dataarray).data.astype(numpy_dtype),
#     297         self,
#     298         lock=lock,
#     299         compute=compute,
#     300     )
#
# File rasterio/_base.pyx:448, in rasterio._base.DatasetBase.__exit__()
#
# File rasterio/_base.pyx:439, in rasterio._base.DatasetBase.close()
#
# File ~/opt/miniconda3/envs/planet/lib/python3.8/contextlib.py:531, in ExitStack.close(self)
#     528             raise
#     529     return received_exc and suppressed_exc
# --> 531 def close(self):
#     532     """Immediately unwind the context stack."""
#     533     self.__exit__(None, None, None)
#
# KeyboardInterrupt:

# %%
mask_reproject_easymore = mask.to_crs(epsg=4326)
print("mask crs:", mask_reproject_easymore.crs)
# Out:
# mask crs: EPSG:4326

# %%
mask_reproject_easymore.to_file("mask_easymore.shp")
print('file written.')
# Out:
# file written.

# %%
# Out:
# <xarray.Variable (band: 1, y: 9422, x: 6984)>
# [65803248 values with dtype=float32]
# Attributes:
#     AREA_OR_POINT:  Area

# %% [markdown]
# ## Remapping

# %%
# Check written ndvi file
filename = 'NDVI_time_attempt2.nc'
ndvi_dataset = xr.open_dataset(filename)
ndvi_dataset
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 3160, lon: 4990)
# Coordinates:
#   * lat      (lat) float64 3.611e+06 3.611e+06 3.611e+06 ... 3.627e+06 3.627e+06
#   * lon      (lon) float64 2.854e+05 2.854e+05 2.854e+05 ... 3.104e+05 3.104e+05
# Data variables: (12/30)
#     Band1    (lat, lon) float32 ...
#     Band2    (lat, lon) float32 ...
#     Band3    (lat, lon) float32 ...
#     Band4    (lat, lon) float32 ...
#     Band5    (lat, lon) float32 ...
#     Band6    (lat, lon) float32 ...
#     ...       ...
#     Band25   (lat, lon) float32 ...
#     Band26   (lat, lon) float32 ...
#     Band27   (lat, lon) float32 ...
#     Band28   (lat, lon) float32 ...
#     Band29   (lat, lon) float32 ...
#     Band30   (lat, lon) float32 ...
# Attributes:
#     Conventions:       CF-1.5
#     GDAL:              GDAL 3.6.3, released 2023/03/07
#     history:           Mon Apr 10 16:30:19 2023: GDAL Create( NDVI_time_attem...
#     GDAL_description:  Calculated NDVI

# %%
# %% Now remapping following this tutorial
# https://github.com/ShervanGharari/EASYMORE/blob/main/examples/Chapter1_E1.ipynb
# # loading EASYMORE
from easymore.easymore import easymore

# initializing EASYMORE object
esmr = easymore()

# specifying EASYMORE objects
# name of the case; the temporary, remapping and remapped file names include case name
esmr.case_name                = 'ndvi_remapping'              
# temporary path that the EASYMORE generated GIS files and remapped file will be saved
esmr.temp_dir                 = '../temporary/'

# name of target shapefile that the source netcdf files should be remapped to
# It needs me to reproject my shapefile to WGS84 (epsg:4326)
#       Note: It said please
esmr.target_shp = 'mask_easymore.shp'


# name of netCDF file(s); multiple files can be specified with *
esmr.source_nc                = 'NDVI_time.nc'

# name of variables from source netCDF file(s) to be remapped
esmr.var_names                = ["NDVI"]
# rename the variables from source netCDF file(s) in the remapped files;
# it will be the same as source if not provided
esmr.var_names_remapped       = ["NDVI"]
# name of variable longitude in source netCDF files
esmr.var_lon                  = 'lon'
# name of variable latitude in source netCDF files
esmr.var_lat                  = 'lat'
# name of variable time in source netCDF file; should be always time
esmr.var_time                 = 'time'
# location where the remapped netCDF file will be saved
esmr.output_dir               = 'outputfiles/remapped/'
# format of the variables to be saved in remapped files,
# if one format provided it will be expanded to other variables
esmr.format_list              = ['f4']
# fill values of the variables to be saved in remapped files,
# if one value provided it will be expanded to other variables
esmr.fill_value_list          = ['-9999.00']
# if required that the remapped values to be saved as csv as well
esmr.save_csv                 = True
esmr.complevel                 =  9
# if uncommented EASYMORE will use this and skip GIS tasks
#esmr.remap_csv                = '../temporary/ERA5_Medicine_Hat_remapping.csv'
# Out:
# EASYMORE version 0.0.4 is initiated.

# %%
# execute EASYMORE
esmr.nc_remapper()
# Out:
# no author name is provide and the author name is changed to (author name)!
# EASYMORE will remap variable  NDVI  from source file to variable  NDVI  in remapped NeCDF file
# EASYMORE detects that target shapefile is in WGS84 (epsg:4326)
# EASYMORE detects that no field for ID is provided in sink/target shapefile
# arbitarary values of ID are added in the field ID_t
# EASYMORE detects that either of the fields for latitude or longitude is not provided in sink/target shapefile
# calculating centroid of shapes in WGS84 projection;
# for better appximation use the easymore equal area centroid function to preprocess target shapefile
# EASYMORE detects that no field for latitude is provided in sink/target shapefile
# latitude values are added in the field lat_t
# EASYMORE detects that no field for longitude is provided in sink/target shapefile
# longitude values are added in the field lon_t
# it seems everything is OK with the sink/target shapefile; added to EASYMORE object target_shp_gpd
# EASYMORE will save standard shapefile for EASYMORE claculation as:
# ../temporary/ndvi_remapping_target_shapefile.shp
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 2
#       1 # execute EASYMORE
# ----> 2 esmr.nc_remapper()
#
# File ~/opt/miniconda3/envs/planet/lib/python3.8/site-packages/easymore/easymore.py:80, in easymore.nc_remapper(self)
#      78 target_shp_gpd.to_file(self.temp_dir+self.case_name+'_target_shapefile.shp') # save
#      79 # check the source NetCDF files
# ---> 80 self.check_source_nc()
#      81 # find the case
#      82 self.NetCDF_SHP_lat_lon()
#
# File ~/opt/miniconda3/envs/planet/lib/python3.8/site-packages/easymore/easymore.py:350, in easymore.check_source_nc(self)
#     348 else:
#     349     ncid      = nc4.Dataset(nc_names[0])
# --> 350     var_dim   = list(ncid.variables[self.var_names[0]].dimensions)
#     351     lat_dim   = list(ncid.variables[self.var_lat].dimensions)
#     352     lon_dim   = list(ncid.variables[self.var_lon].dimensions)
#
# KeyError: 'NDVI'
